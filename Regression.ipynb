# %% [markdown]
# <a href="https://colab.research.google.com/github/SHAHAB-UDDIN54/Machine_learning-with-Shah/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Regression :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset  = pd.read_csv("/content/house price.csv")
dataset.head(5)
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         4        1.6         2196      9032     2.0           0     4
# 1         5        2.5         3806      1001     2.5           0     0
# 2         3        2.4         2020      7368     2.0           0     3
# 3         5        3.2         3022     12040     1.5           0     0
# 4         5        3.2         4948     13236     1.0           1     1
#
#    condition  sqft_above  sqft_basement  yr_built  yr_removed    price
# 0          4        1028           1168      2020           0    82966
# 1          2        2718           1088      1962           0   470993
# 2          3         750           1270      2005           0  1354309
# 3          3        2288            734      1953           0   213639
# 4          5        3958            990      1941           0   296331

# %%
dataset.shape
# Out:
# (500, 13)

# %%
dataset.isnull().sum()
# Out:
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_removed       0
# price            0
# dtype: int64

# %%
dataset.describe()
# Out:
#         bedrooms  bathrooms  sqft_living      sqft_lot     floors  waterfront  \
# count  500.00000  500.00000   500.000000    500.000000  500.00000  500.000000
# mean     3.50000    2.75500  3348.248000   8116.522000    2.04400    0.092000
# std      1.72277    1.02652  1168.983466   4128.688081    0.70998    0.289315
# min      1.00000    1.00000   567.000000   1001.000000    1.00000    0.000000
# 25%      2.00000    1.87500  2408.500000   4462.750000    1.50000    0.000000
# 50%      4.00000    2.80000  3463.500000   8108.000000    2.00000    0.000000
# 75%      5.00000    3.60000  4164.250000  11672.750000    2.50000    0.000000
# max      6.00000    4.50000  5895.000000  14994.000000    3.00000    1.000000
#
#              view   condition   sqft_above  sqft_basement     yr_built  \
# count  500.000000  500.000000   500.000000     500.000000   500.000000
# mean     1.986000    2.904000  2336.478000    1011.770000  1960.190000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error

# %%
x = dataset[["bedrooms"]]
y = dataset["price"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state= 42)

# %%
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("predication value",y_pred)
# Out:
# predication value [1047402.82528189 1042399.10774015 1032391.67265665 1047402.82528189
#  1027387.9551149  1032391.67265665 1052406.54282364 1037395.3901984
#  1032391.67265665 1037395.3901984  1047402.82528189 1027387.9551149
#  1027387.9551149  1052406.54282364 1047402.82528189 1027387.9551149
#  1042399.10774015 1037395.3901984  1027387.9551149  1052406.54282364
#  1052406.54282364 1052406.54282364 1042399.10774015 1047402.82528189
#  1032391.67265665 1042399.10774015 1032391.67265665 1027387.9551149
#  1027387.9551149  1052406.54282364 1047402.82528189 1037395.3901984
#  1047402.82528189 1052406.54282364 1037395.3901984  1037395.3901984
#  1042399.10774015 1052406.54282364 1032391.67265665 1052406.54282364
#  1037395.3901984  1027387.9551149  1047402.82528189 1042399.10774015
#  1042399.10774015 1032391.67265665 1042399.10774015 1037395.3901984
#  1037395.3901984  1042399.10774015 1032391.67265665 1037395.3901984
# ...

# %%
print("actual value",y_test)
# Out:
# actual value 361     516995
# 73     1677826
# 374     946197
# 155     400068
# 104    1409385
#         ...
# 347     354962
# 86     1327082
# 75     1659425
# 438    1639426
# 15     1053510
# Name: price, Length: 100, dtype: int64

# %%
mse = mean_squared_error(y_test,y_pred)
print("mean squared error",mse)
# Out:
# mean squared error 310466903016.0433

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_test,y_test,color="red")
plt.show()

# %%
plt.plot(x,model.predict(x),color="blue")

plt.xlabel("BADROOMS")
plt.ylabel("PRICE")
plt.title("LINEAR REGRESSION")
plt.show()
